# %%
import numpy as np
import cv2
import time
import os
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
# %matplotlib inline


from imutils.object_detection import non_max_suppression
from mpl_toolkits.axes_grid1 import ImageGrid

# %%
# example image path

fileName = "starbucks_0.jpg"
filePath = f"Data\images\Starbucks\{fileName}"

# %%
# Display an image with grid

img = cv2.imread(filePath)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.show()

# %%
# reference : 
# EAST (Efficient accurate scene text detector)
# https://medium.com/technovators/scene-text-detection-in-python-with-east-and-craft-cbe03dda35d5

def create_mask(image):
    layerNames = [
        "feature_fusion/Conv_7/Sigmoid",
        "feature_fusion/concat_3"]

    inp_mask = image.copy()

    if len(image.shape) == 2:
        image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

    (img_H, img_W) = image.shape[:2]

    # set the new width and height and then determine the ratio in change
    # for both the width and height: Should be multiple of 32
    (newW, newH) = (320, 320)

    rW = img_W / float(newW)
    rH = img_H / float(newH)

    # resize the image and grab the new image dimensions
    r_img = cv2.resize(image, (newW, newH))

    (H, W) = r_img.shape[:2]

    net = cv2.dnn.readNet("model/frozen_east_text_detection.pb")

    blob = cv2.dnn.blobFromImage(r_img, 1.0, (W, H),
                                 (123.68, 116.78, 103.94), swapRB=True, crop=False)

    start = time.time()

    net.setInput(blob)

    (scores, geometry) = net.forward(layerNames)

    (numRows, numCols) = scores.shape[2:4]
    rects = []
    confidences = []


    # loop over the number of rows
    for y in range(0, numRows):
        # extract the scores (probabilities), followed by the geometrical
        # data used to derive potential bounding box coordinates that
        # surround text
        scoresData = scores[0, 0, y]
        xData0 = geometry[0, 0, y]
        xData1 = geometry[0, 1, y]
        xData2 = geometry[0, 2, y]
        xData3 = geometry[0, 3, y]
        anglesData = geometry[0, 4, y]

        for x in range(0, numCols):
            # if our score does not have sufficient probability, ignore it
            # Set minimum confidence as required
            if scoresData[x] < 0.5:
                continue
                
            # compute the offset factor as our resulting feature maps will
            #  x smaller than the input image
            (offsetX, offsetY) = (x * 4.0, y * 4.0)
            
            # extract the rotation angle for the prediction and then
            # compute the sin and cosine
            angle = anglesData[x]
            cos = np.cos(angle)
            sin = np.sin(angle)
            
            # use the geometry volume to derive the width and height of
            # the bounding box
            h = xData0[x] + xData2[x]
            w = xData1[x] + xData3[x]
            
            # compute both the starting and ending (x, y)-coordinates for
            # the text prediction bounding box
            endX = int(offsetX + (cos * xData1[x]) + (sin * xData2[x]))
            endY = int(offsetY - (sin * xData1[x]) + (cos * xData2[x]))
            startX = int(endX - w)
            startY = int(endY - h)
            
            # add the bounding box coordinates and probability score to
            # our respective lists
            rects.append((startX, startY, endX, endY))
            confidences.append(scoresData[x])

    boxes = non_max_suppression(np.array(rects), probs=confidences)

    # change background color for mark image to black
    cv2.rectangle(inp_mask, (0, 0), (img_W, img_H), (0, 0, 0), -1)

    # loop over the bounding boxes
    for (startX, startY, endX, endY) in boxes:
        # scale the bounding box coordinates based on the respective
        # ratios
        startX = int(startX * rW)
        startY = int(startY * rH)
        endX = int(endX * rW)
        endY = int(endY * rH)

        # draw the white bounding box on the mark image
        cv2.rectangle(inp_mask, (startX, startY), (endX, endY), (255, 255, 255), -1)

    # Converting image to 8-bit 1-channel image
    inp_mask = cv2.cvtColor(inp_mask, cv2.COLOR_BGR2GRAY)
    
    return inp_mask

# %%
mask = create_mask(img)
mask  = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)

plt.imshow(mask)
plt.show()

# %%
# Detect letters and create masked image

def create_masked_img(image):
    layerNames = [
        "feature_fusion/Conv_7/Sigmoid",
        "feature_fusion/concat_3"]

    inp_mask = image.copy()

    if len(image.shape) == 2:
        image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

    (img_H, img_W) = image.shape[:2]

    # set the new width and height and then determine the ratio in change
    # for both the width and height: Should be multiple of 32
    (newW, newH) = (320, 320)

    rW = img_W / float(newW)
    rH = img_H / float(newH)

    # resize the image and grab the new image dimensions
    r_img = cv2.resize(image, (newW, newH))

    (H, W) = r_img.shape[:2]

    net = cv2.dnn.readNet("model/frozen_east_text_detection.pb")

    blob = cv2.dnn.blobFromImage(r_img, 1.0, (W, H),
                                 (123.68, 116.78, 103.94), swapRB=True, crop=False)

    start = time.time()

    net.setInput(blob)

    (scores, geometry) = net.forward(layerNames)

    (numRows, numCols) = scores.shape[2:4]
    rects = []
    confidences = []


    # loop over the number of rows
    for y in range(0, numRows):
        # extract the scores (probabilities), followed by the geometrical
        # data used to derive potential bounding box coordinates that
        # surround text
        scoresData = scores[0, 0, y]
        xData0 = geometry[0, 0, y]
        xData1 = geometry[0, 1, y]
        xData2 = geometry[0, 2, y]
        xData3 = geometry[0, 3, y]
        anglesData = geometry[0, 4, y]

        for x in range(0, numCols):
            # if our score does not have sufficient probability, ignore it
            # Set minimum confidence as required
            if scoresData[x] < 0.5:
                continue
                
            # compute the offset factor as our resulting feature maps will
            #  x smaller than the input image
            (offsetX, offsetY) = (x * 4.0, y * 4.0)
            
            # extract the rotation angle for the prediction and then
            # compute the sin and cosine
            angle = anglesData[x]
            cos = np.cos(angle)
            sin = np.sin(angle)
            
            # use the geometry volume to derive the width and height of
            # the bounding box
            h = xData0[x] + xData2[x]
            w = xData1[x] + xData3[x]
            
            # compute both the starting and ending (x, y)-coordinates for
            # the text prediction bounding box
            endX = int(offsetX + (cos * xData1[x]) + (sin * xData2[x]))
            endY = int(offsetY - (sin * xData1[x]) + (cos * xData2[x]))
            startX = int(endX - w)
            startY = int(endY - h)
            
            # add the bounding box coordinates and probability score to
            # our respective lists
            rects.append((startX, startY, endX, endY))
            confidences.append(scoresData[x])

    boxes = non_max_suppression(np.array(rects), probs=confidences)


    # loop over the bounding boxes
    for (startX, startY, endX, endY) in boxes:
        # scale the bounding box coordinates based on the respective
        # ratios
        startX = int(startX * rW)
        startY = int(startY * rH)
        endX = int(endX * rW)
        endY = int(endY * rH)

        # draw the white bounding box on the mark image
        cv2.rectangle(inp_mask, (startX, startY), (endX, endY), (0, 0, 0), -1)

    inp_mask = cv2.cvtColor(inp_mask, cv2.COLOR_BGR2RGB)
    return inp_mask

# %%
# test an example for the create_masked_img function

masked_img = create_masked_img(img)

plt.imshow(masked_img)
plt.show()

# %%
# example image path

fileName = "Costa_0.jpg"
filePath = f"Data\images\Costa coffee\{fileName}"

img = cv2.imread(filePath)
masked_img = create_masked_img(img)

plt.imshow(masked_img)
plt.show()

# %%
import os

categories = ["Costa coffee","Costco", "Hobby lobby", "Starbucks", "Target"]

for cat in categories:
    path = f'Data\images\{cat}'
    files = os.listdir(path)
    
    for f in files:
        fNameArray = os.path.splitext(f)
        l = len(fNameArray) 
        ext = fNameArray[l-1]
        
        if(ext == ".jpg"):
            filePath = f"{path}\{f}"
            maskPath = f"Data\masked_images\masked_{f}"
            
            image = cv2.imread(filePath)
            masked_img = create_masked_img(image)
            
            pil_image=Image.fromarray(masked_img)
            pil_image.save(maskPath)
#             print(f"{path}\{f}")
        else:
            next
